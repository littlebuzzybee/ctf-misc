# %%
import base64

# %%
s = "..."
for _ in range(21):
    s = base64.b64decode(s)
    print(s)
# Out:
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b'...'
# b''
# b''
# ...
